# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Creating a dummy dataframe

# %%
df_dict = dict()

df_dict['A'] = [1,2,3,4,5]
dummy = pd.DataFrame(df_dict  )

# %%
dummy
# Out:
#    A
# 0  1
# 1  2
# 2  3
# 3  4
# 4  5

# %% [markdown]
# ## Loading the datasets

# %%
df_train = pd.read_csv('train.csv')
df_test = pd.read_csv('test.csv')

# %%
## calling the variables only in a cell will print their result
df_train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
##df_test

# %%
# Checking the datatype => Pandas Dataframe
print(type(df_test))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# ## Let's Join the two datasets together to form a single dataset

# %%
##Defining a function or even creating a python class

# with function 

def join(train, test):
    copy_train = train.copy()
    copy_test = test.copy()
    
    copy_train.drop(['Survived'], 1, inplace=True)
    
    return copy_train.append(copy_test)

# Will explain this better at the end of the class

# %%
df = join(df_train, df_test)

# %%
df
# Out:
#      PassengerId  Pclass                                               Name  \
# 0              1       3                            Braund, Mr. Owen Harris
# 1              2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3       3                             Heikkinen, Miss. Laina
# 3              4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5       3                           Allen, Mr. William Henry
# ..           ...     ...                                                ...
# 413         1305       3                                 Spector, Mr. Woolf
# 414         1306       1                       Oliva y Ocana, Dona. Fermina
# 415         1307       3                       Saether, Mr. Simon Sivertsen
# 416         1308       3                                Ware, Mr. Frederick
# 417         1309       3                           Peter, Master. Michael J
#
# ...

# %% [markdown]
# ### Getting the head

# %%
## default parameter for the head method on the dataframe is 5, however integers could be specified
###i.e df.head(10)
df.head()
# Out:
#    PassengerId  Pclass                                               Name  \
# 0            1       3                            Braund, Mr. Owen Harris
# 1            2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2            3       3                             Heikkinen, Miss. Laina
# 3            4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4            5       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S

# %%
### Getting the tail

# %%
### same thing applies to tail method

df.tail()
# Out:
#      PassengerId  Pclass                          Name     Sex   Age  SibSp  \
# 413         1305       3            Spector, Mr. Woolf    male   NaN      0
# 414         1306       1  Oliva y Ocana, Dona. Fermina  female  39.0      0
# 415         1307       3  Saether, Mr. Simon Sivertsen    male  38.5      0
# 416         1308       3           Ware, Mr. Frederick    male   NaN      0
# 417         1309       3      Peter, Master. Michael J    male   NaN      1
#
#      Parch              Ticket      Fare Cabin Embarked
# 413      0           A.5. 3236    8.0500   NaN        S
# 414      0            PC 17758  108.9000  C105        C
# 415      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416      0              359309    8.0500   NaN        S
# 417      1                2668   22.3583   NaN        C

# %% [markdown]
# ## Getting the Dimension of our dataframe i.e shape

# %%
df.shape
# Out:
# (1309, 11)

# %% [markdown]
# ### Getting info about the dataframe

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 0 to 417
# Data columns (total 11 columns):
# PassengerId    1309 non-null int64
# Pclass         1309 non-null int64
# Name           1309 non-null object
# Sex            1309 non-null object
# Age            1046 non-null float64
# SibSp          1309 non-null int64
# Parch          1309 non-null int64
# Ticket         1309 non-null object
# Fare           1308 non-null float64
# Cabin          295 non-null object
# Embarked       1307 non-null object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 122.7+ KB

# %%
## getting the columns
df.columns
# print(type(df.columns))
# print(type(df.columns.values))
# Out:
# Index(['PassengerId', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
## converting the columns to list

features = df.columns.to_list()

# %%
features
# Out:
# ['PassengerId',
#  'Pclass',
#  'Name',
#  'Sex',
#  'Age',
#  'SibSp',
#  'Parch',
#  'Ticket',
#  'Fare',
#  'Cabin',
#  'Embarked']

# %% [markdown]
# ### Getting Specific columns(feature)

# %%
## A dot notation may be used
df.Pclass
# Out:
# 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 413    3
# 414    1
# 415    3
# 416    3
# 417    3
# Name: Pclass, Length: 1309, dtype: int64

# %%
## Using bracket notation

df['Pclass']

##  df['Pclass'].values returns a numpy array of the values of the column
## df['Pclass'].head() could be used to get thew head of the column
# Out:
# 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 413    3
# 414    1
# 415    3
# 416    3
# 417    3
# Name: Pclass, Length: 1309, dtype: int64

# %% [markdown]
# ## locating stuffs with iloc and loc

# %%
## df.iloc[row, column]
## df.loc[condition]

## selecting the 2nd row
df.iloc[2]
# Out:
# PassengerId                         3
# Pclass                              3
# Name           Heikkinen, Miss. Laina
# Sex                            female
# Age                                26
# SibSp                               0
# Parch                               0
# Ticket               STON/O2. 3101282
# Fare                            7.925
# Cabin                             NaN
# Embarked                            S
# Name: 2, dtype: object

# %%
## slicing to select rows and columns, try more advanced stuffs with that.
df.iloc[10:20, :10]
# Out:
#     PassengerId  Pclass                                               Name  \
# 10           11       3                    Sandstrom, Miss. Marguerite Rut
# 11           12       1                           Bonnell, Miss. Elizabeth
# 12           13       3                     Saundercock, Mr. William Henry
# 13           14       3                        Andersson, Mr. Anders Johan
# 14           15       3               Vestrom, Miss. Hulda Amanda Adolfina
# 15           16       2                   Hewlett, Mrs. (Mary D Kingcome)
# 16           17       3                               Rice, Master. Eugene
# 17           18       2                       Williams, Mr. Charles Eugene
# 18           19       3  Vander Planke, Mrs. Julius (Emelia Maria Vande...
# 19           20       3                            Masselmani, Mrs. Fatima
#
#        Sex   Age  SibSp  Parch     Ticket     Fare Cabin
# 10  female   4.0      1      1    PP 9549  16.7000    G6
# ...

# %%
## selecting data where Pclass is less than 3, that's the meaning of the above code
df.loc[ df['Pclass'] < 3]
# Out:
#      PassengerId  Pclass                                               Name  \
# 1              2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3              4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 6              7       1                            McCarthy, Mr. Timothy J
# 9             10       2                Nasser, Mrs. Nicholas (Adele Achem)
# 11            12       1                           Bonnell, Miss. Elizabeth
# ..           ...     ...                                                ...
# 405         1297       2       Nourney, Mr. Alfred (Baron von Drachstedt")"
# 406         1298       2                          Ware, Mr. William Jeffery
# 407         1299       1                         Widener, Mr. George Dunton
# 411         1303       1    Minahan, Mrs. William Edward (Lillian E Thorpe)
# 414         1306       1                       Oliva y Ocana, Dona. Fermina
#
# ...

# %%
## Iterating through a df, selecting any feature(column)
for i,j in df.iterrows():
    print(i,j['Pclass'])
# Out:
# 0 3
# 1 1
# 2 3
# 3 1
# 4 3
# 5 3
# 6 1
# 7 3
# 8 3
# 9 2
# 10 3
# 11 1
# 12 3
# 13 3
# 14 3
# 15 2
# 16 3
# 17 2
# 18 3
# 19 3
# 20 2
# 21 2
# 22 3
# 23 1
# 24 3
# 25 3
# 26 3
# 27 1
# 28 3
# 29 3
# 30 1
# 31 1
# 32 3
# 33 2
# 34 1
# 35 1
# 36 3
# 37 3
# 38 3
# 39 3
# 40 3
# 41 2
# 42 3
# 43 2
# 44 3
# 45 3
# 46 3
# 47 3
# 48 3
# 49 3
# 50 3
# 51 3
# 52 1
# 53 2
# 54 1
# 55 1
# 56 2
# 57 3
# 58 2
# 59 3
# 60 3
# 61 1
# 62 1
# 63 3
# 64 1
# 65 3
# 66 2
# 67 3
# 68 3
# 69 3
# 70 2
# 71 3
# 72 2
# 73 3
# 74 3
# 75 3
# 76 3
# 77 3
# 78 2
# 79 3
# 80 3
# 81 3
# 82 3
# 83 1
# 84 2
# 85 3
# 86 3
# 87 3
# 88 1
# 89 3
# 90 3
# 91 3
# 92 1
# 93 3
# 94 3
# 95 3
# 96 1
# 97 1
# 98 2
# 99 2
# 100 3
# 101 3
# 102 1
# 103 3
# 104 3
# 105 3
# 106 3
# 107 3
# 108 3
# 109 3
# 110 1
# 111 3
# 112 3
# 113 3
# 114 3
# 115 3
# 116 3
# 117 2
# 118 1
# 119 3
# 120 2
# 121 3
# 122 2
# 123 2
# 124 1
# 125 3
# 126 3
# 127 3
# 128 3
# 129 3
# 130 3
# 131 3
# 132 3
# 133 2
# 134 2
# 135 2
# 136 1
# 137 1
# ...

# %% [markdown]
# ## Statistics

# %%
df.describe()
# Out:
#        PassengerId       Pclass          Age        SibSp        Parch  \
# count  1309.000000  1309.000000  1046.000000  1309.000000  1309.000000
# mean    655.000000     2.294882    29.881138     0.498854     0.385027
# std     378.020061     0.837836    14.413493     1.041658     0.865560
# min       1.000000     1.000000     0.170000     0.000000     0.000000
# 25%     328.000000     2.000000    21.000000     0.000000     0.000000
# 50%     655.000000     3.000000    28.000000     0.000000     0.000000
# 75%     982.000000     3.000000    39.000000     1.000000     0.000000
# max    1309.000000     3.000000    80.000000     8.000000     9.000000
#
#               Fare
# count  1308.000000
# mean     33.295479
# std      51.758668
# min       0.000000
# 25%       7.895800
# 50%      14.454200
# 75%      31.275000
# max     512.329200

# %%
## Mean of each numerical feature
df.mean()
# Out:
# PassengerId    655.000000
# Pclass           2.294882
# Age             29.881138
# SibSp            0.498854
# Parch            0.385027
# Fare            33.295479
# dtype: float64

# %%
## mode of a column
df['Pclass'].mode()
# Out:
# 0    3
# dtype: int64

# %%
## standard deviation
df['Pclass'].std()

## try other methods on the dataframe object
# Out:
# 0.8378360189701319

# %%
df
# Out:
#      PassengerId  Pclass                                               Name  \
# 0              1       3                            Braund, Mr. Owen Harris
# 1              2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3       3                             Heikkinen, Miss. Laina
# 3              4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5       3                           Allen, Mr. William Henry
# ..           ...     ...                                                ...
# 413         1305       3                                 Spector, Mr. Woolf
# 414         1306       1                       Oliva y Ocana, Dona. Fermina
# 415         1307       3                       Saether, Mr. Simon Sivertsen
# 416         1308       3                                Ware, Mr. Frederick
# 417         1309       3                           Peter, Master. Michael J
#
# ...

# %%
## Sorting Values
## This sorts the dataframe based on the ascending order of the Fare.

df.sort_values(['Fare'], ascending=False)
# Out:
#      PassengerId  Pclass                                               Name  \
# 258          259       1                                   Ward, Miss. Anna
# 679          680       1                 Cardeza, Mr. Thomas Drake Martinez
# 343         1235       1  Cardeza, Mrs. James Warburton Martinez (Charlo...
# 737          738       1                             Lesurer, Mr. Gustave J
# 341          342       1                     Fortune, Miss. Alice Elizabeth
# ..           ...     ...                                                ...
# 815          816       1                                   Fry, Mr. Richard
# 302          303       3                    Johnson, Mr. William Cahoone Jr
# 806          807       1                             Andrews, Mr. Thomas Jr
# 263          264       1                              Harrison, Mr. William
# 152         1044       3                                 Storey, Mr. Thomas
#
# ...

# %%
## Creating a new column 

df['new_column'] = np.log(df['Fare'])
# Out:
# C:\Users\Hameed\Anaconda3\lib\site-packages\pandas\core\series.py:853: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %% [markdown]
# ## Dropping Columns

# %%
## columns could be dropped by:
### 1 assigning the dataframe to a dataframe being dropped
### 2 or by setting inplace to True
### .drop method receive the feature name as the first argument and axis as the second axis could be (0,1):=> row or column respectively


df.drop('PassengerId', 1, inplace =True)

#### or

## df = df.drop('Name', 1)

# %%
df
# Out:
#      Pclass                                               Name     Sex   Age  \
# 0         3                            Braund, Mr. Owen Harris    male  22.0
# 1         1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2         3                             Heikkinen, Miss. Laina  female  26.0
# 3         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4         3                           Allen, Mr. William Henry    male  35.0
# ..      ...                                                ...     ...   ...
# 413       3                                 Spector, Mr. Woolf    male   NaN
# 414       1                       Oliva y Ocana, Dona. Fermina  female  39.0
# 415       3                       Saether, Mr. Simon Sivertsen    male  38.5
# 416       3                                Ware, Mr. Frederick    male   NaN
# 417       3                           Peter, Master. Michael J    male   NaN
#
# ...

# %% [markdown]
# ### Getting unique values

# %%
### df['feature'].value_counts() | df['featues'].unique()
df['Pclass'].value_counts()
# Out:
# 3    709
# 1    323
# 2    277
# Name: Pclass, dtype: int64

# %%
df['Pclass'].unique()
# Out:
# array([3, 1, 2], dtype=int64)

# %%
df['Sex'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %% [markdown]
# ### conditional changes

# %%
## changing values with condition.

### This case, if pclass is greater than or equal 2, change values of pclass to senior
df.loc[ df['Pclass'] >= 2 , ['Pclass'] ] = 'Senior'

# %%
df.loc[ df['Pclass'] == 1 , ['Pclass'] ] = 'junior'

# %%
df
# Out:
#      Pclass                                               Name     Sex   Age  \
# 0    Senior                            Braund, Mr. Owen Harris    male  22.0
# 1    junior  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2    Senior                             Heikkinen, Miss. Laina  female  26.0
# 3    junior       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4    Senior                           Allen, Mr. William Henry    male  35.0
# ..      ...                                                ...     ...   ...
# 413  Senior                                 Spector, Mr. Woolf    male   NaN
# 414  junior                       Oliva y Ocana, Dona. Fermina  female  39.0
# 415  Senior                       Saether, Mr. Simon Sivertsen    male  38.5
# 416  Senior                                Ware, Mr. Frederick    male   NaN
# 417  Senior                           Peter, Master. Michael J    male   NaN
#
# ...

# %%
df['Married'] = np.zeros(len(df))
df.loc[ df['Name'].str.contains('Mr'), ['Married'] ] = 1

df.loc[ df['Name'].str.contains('Miss'), ['Married'] ] = 0

# %%
df
# Out:
#      Pclass                                               Name     Sex   Age  \
# 0    Senior                            Braund, Mr. Owen Harris    male  22.0
# 1    junior  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2    Senior                             Heikkinen, Miss. Laina  female  26.0
# 3    junior       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4    Senior                           Allen, Mr. William Henry    male  35.0
# ..      ...                                                ...     ...   ...
# 413  Senior                                 Spector, Mr. Woolf    male   NaN
# 414  junior                       Oliva y Ocana, Dona. Fermina  female  39.0
# 415  Senior                       Saether, Mr. Simon Sivertsen    male  38.5
# 416  Senior                                Ware, Mr. Frederick    male   NaN
# 417  Senior                           Peter, Master. Michael J    male   NaN
#
# ...

# %%
### .replace method could also be used

### meaning replace male and female with 1 and 0 respecticely

df['Sex'].replace(['male', 'female'], [1,0], inplace=True)

# %%
df
# Out:
#      Pclass                                               Name  Sex   Age  \
# 0    Senior                            Braund, Mr. Owen Harris    1  22.0
# 1    junior  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0
# 2    Senior                             Heikkinen, Miss. Laina    0  26.0
# 3    junior       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0
# 4    Senior                           Allen, Mr. William Henry    1  35.0
# ..      ...                                                ...  ...   ...
# 413  Senior                                 Spector, Mr. Woolf    1   NaN
# 414  junior                       Oliva y Ocana, Dona. Fermina    0  39.0
# 415  Senior                       Saether, Mr. Simon Sivertsen    1  38.5
# 416  Senior                                Ware, Mr. Frederick    1   NaN
# 417  Senior                           Peter, Master. Michael J    1   NaN
#
#      SibSp  Parch              Ticket      Fare Cabin Embarked  new_column  \
# ...

# %%
df.drop('Name', 1, inplace=True)

# %%
df
# Out:
#      Pclass  Sex   Age  SibSp  Parch              Ticket      Fare Cabin  \
# 0    Senior    1  22.0      1      0           A/5 21171    7.2500   NaN
# 1    junior    0  38.0      1      0            PC 17599   71.2833   C85
# 2    Senior    0  26.0      0      0    STON/O2. 3101282    7.9250   NaN
# 3    junior    0  35.0      1      0              113803   53.1000  C123
# 4    Senior    1  35.0      0      0              373450    8.0500   NaN
# ..      ...  ...   ...    ...    ...                 ...       ...   ...
# 413  Senior    1   NaN      0      0           A.5. 3236    8.0500   NaN
# 414  junior    0  39.0      0      0            PC 17758  108.9000  C105
# 415  Senior    1  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN
# 416  Senior    1   NaN      0      0              359309    8.0500   NaN
# 417  Senior    1   NaN      1      1                2668   22.3583   NaN
#
#     Embarked  new_column  Married
# 0          S    1.981001      1.0
# ...

# %%
df.drop('Ticket', 1, inplace=True)

# %%
df
# Out:
#      Pclass  Sex   Age  SibSp  Parch      Fare Cabin Embarked  new_column  \
# 0    Senior    1  22.0      1      0    7.2500   NaN        S    1.981001
# 1    junior    0  38.0      1      0   71.2833   C85        C    4.266662
# 2    Senior    0  26.0      0      0    7.9250   NaN        S    2.070022
# 3    junior    0  35.0      1      0   53.1000  C123        S    3.972177
# 4    Senior    1  35.0      0      0    8.0500   NaN        S    2.085672
# ..      ...  ...   ...    ...    ...       ...   ...      ...         ...
# 413  Senior    1   NaN      0      0    8.0500   NaN        S    2.085672
# 414  junior    0  39.0      0      0  108.9000  C105        C    4.690430
# 415  Senior    1  38.5      0      0    7.2500   NaN        S    1.981001
# 416  Senior    1   NaN      0      0    8.0500   NaN        S    2.085672
# 417  Senior    1   NaN      1      1   22.3583   NaN        C    3.107198
#
#      Married
# 0        1.0
# 1        1.0
# 2        0.0
# 3        1.0
# ...

# %%
df['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %% [markdown]
# ### Doing some data cleaning with pandas part of EDA

# %%
## Getting the sum of null fields
df.isnull().sum()
# Out:
# Pclass           0
# Sex              0
# Age            263
# SibSp            0
# Parch            0
# Fare             1
# Cabin         1014
# Embarked         2
# new_column       1
# Married          0
# dtype: int64

# %%
### Filling empty, or nan fields
### df[feature].fillna(df[feature].mean(), inplace=True)
df['Embarked'].fillna(df['Embarked'].mode()[0], inplace=True)

# %%
df.isnull().sum()
# Out:
# Pclass           0
# Sex              0
# Age            263
# SibSp            0
# Parch            0
# Fare             1
# Cabin         1014
# Embarked         0
# new_column       1
# Married          0
# dtype: int64

# %%
df['Age'].fillna(df['Age'].mean(), inplace=True)

# %%
df.drop('Cabin', 1, inplace=True)

# %%
df['new_column'].fillna(df['new_column'].mean(), inplace=True)

# %%
df['Fare'].fillna(df['Fare'].mean(), inplace=True)

# %%
df.isnull().sum()
# Out:
# Pclass        0
# Sex           0
# Age           0
# SibSp         0
# Parch         0
# Fare          0
# Embarked      0
# new_column    0
# Married       0
# dtype: int64

# %%
df
# Out:
#      Pclass  Sex        Age  SibSp  Parch      Fare Embarked  new_column  \
# 0    Senior    1  22.000000      1      0    7.2500        S    1.981001
# 1    junior    0  38.000000      1      0   71.2833        C    4.266662
# 2    Senior    0  26.000000      0      0    7.9250        S    2.070022
# 3    junior    0  35.000000      1      0   53.1000        S    3.972177
# 4    Senior    1  35.000000      0      0    8.0500        S    2.085672
# ..      ...  ...        ...    ...    ...       ...      ...         ...
# 413  Senior    1  29.881138      0      0    8.0500        S    2.085672
# 414  junior    0  39.000000      0      0  108.9000        C    4.690430
# 415  Senior    1  38.500000      0      0    7.2500        S    1.981001
# 416  Senior    1  29.881138      0      0    8.0500        S    2.085672
# 417  Senior    1  29.881138      1      1   22.3583        C    3.107198
#
#      Married
# 0        1.0
# 1        1.0
# 2        0.0
# 3        1.0
# 4        1.0
# ...

# %% [markdown]
# ## Saving new file

# %%
df.to_csv('cleaned.csv', index=False)

# %%
cleaned = pd.read_csv('cleaned.csv')

# %%
cleaned
# Out:
#       Pclass  Sex        Age  SibSp  Parch      Fare Embarked  new_column  \
# 0     Senior    1  22.000000      1      0    7.2500        S    1.981001
# 1     junior    0  38.000000      1      0   71.2833        C    4.266662
# 2     Senior    0  26.000000      0      0    7.9250        S    2.070022
# 3     junior    0  35.000000      1      0   53.1000        S    3.972177
# 4     Senior    1  35.000000      0      0    8.0500        S    2.085672
# ...      ...  ...        ...    ...    ...       ...      ...         ...
# 1304  Senior    1  29.881138      0      0    8.0500        S    2.085672
# 1305  junior    0  39.000000      0      0  108.9000        C    4.690430
# 1306  Senior    1  38.500000      0      0    7.2500        S    1.981001
# 1307  Senior    1  29.881138      0      0    8.0500        S    2.085672
# 1308  Senior    1  29.881138      1      1   22.3583        C    3.107198
#
#       Married
# 0         1.0
# 1         1.0
# 2         0.0
# 3         1.0
# ...

# %%
print('Welldone, Good Luck')
# Out:
# Welldone, Good Luck
